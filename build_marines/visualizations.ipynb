# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
dqn_001_df=pd.read_csv('DQN_data_0.01.csv', header=None, names=['Episode', 'Score', 'AvgScore'])
dqn_0001_df=pd.read_csv('DQN_data_0.001.csv', header=None, names=['Episode', 'Score', 'AvgScore'])
dqn_00001_df=pd.read_csv('DQN_data_0.0001.csv', header=None, names=['Episode', 'Score', 'AvgScore'])

# %%
plt.figure(figsize=(6, 6))
sns.scatterplot(data=dqn_001_df, x='Episode', y='Score')

# Customize the plot
plt.title('Score over Episodes')
plt.xlabel('Episode')
plt.ylabel('Score')

# Add a trend line
sns.regplot(data=df, x='Episode', y='Score', scatter=False, color='red')

# Show the plot
plt.show()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20, 6))
sns.scatterplot(data=dqn_001_df, x='Episode', y='Score', ax=ax1)
sns.regplot(data=dqn_001_df, x='Episode', y='Score', scatter=False, color='red', ax=ax1)
ax1.set_title('Score over Episodes (DQN lr=1e-2)')
ax1.set_xlabel('Episode')
ax1.set_ylabel('Score')

sns.scatterplot(data=dqn_0001_df, x='Episode', y='Score', ax=ax2)
sns.regplot(data=dqn_0001_df, x='Episode', y='Score', scatter=False, color='red', ax=ax2)
ax2.set_title('Score over Episodes (DQN lr=1e-3)')
ax2.set_xlabel('Episode')
ax2.set_ylabel('Score')

sns.scatterplot(data=dqn_00001_df, x='Episode', y='Score', ax=ax3)
sns.regplot(data=dqn_00001_df, x='Episode', y='Score', scatter=False, color='red', ax=ax3)
ax3.set_title('Score over Episodes (DQN lr=1e-4)')
ax3.set_xlabel('Episode')
ax3.set_ylabel('Score')
# Out:
# Text(0, 0.5, 'Score')

# %%
ac_1e_5_df = pd.read_csv('actor_critic_data_1e-05.csv', header=None, names=['Episode', 'Score', 'AvgScore'])
ac_1e_6_df = pd.read_csv('actor_critic_data_1e-06.csv', header=None, names=['Episode', 'Score', 'AvgScore'])

# %%
ac_1e_5_df
# Out:
#     Episode  Score  AvgScore
# 0         0    4.0  4.000000
# 1         1    4.0  4.000000
# 2         2    4.0  4.000000
# 3         3    1.0  3.250000
# 4         4    4.0  3.400000
# ..      ...    ...       ...
# 95       95    0.0  2.416667
# 96       96    0.0  2.391753
# 97       97    0.0  2.367347
# 98       98    1.0  2.353535
# 99       99    0.0  2.330000
#
# [100 rows x 3 columns]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 6))
sns.scatterplot(ac_1e_5_df, x='Episode', y='Score', ax=ax1)
sns.regplot(ac_1e_5_df, x='Episode', y='Score', scatter=False, color='red', ax=ax1)
ax1.set_title('Score over Episodes (Actor-Critic  lr=1e-5)')
ax1.set_xlabel('Episode')
ax1.set_ylabel('Score')

sns.scatterplot(data=ac_1e_6_df, x='Episode', y='Score', ax=ax2)
sns.regplot(data=ac_1e_6_df, x='Episode', y='Score', scatter=False, color='red', ax=ax2)
ax2.set_title('Score over Episodes (Actor-Critic lr=1e-6)')
ax2.set_xlabel('Episode')
ax2.set_ylabel('Score')
# Out:
# Text(0, 0.5, 'Score')
